# %% [markdown]
# # Advanced Python
# ## **Data Wrangling**

# %% [markdown]
# ----

# %% [markdown]
#  ### **Topics**
# **1. Feature Transformation of Datasets**           ----- CONTINUE
#  * Random Sampling
#  * String Manipulation

# %% [markdown]
# ----

# %% [markdown]
# ## 1. Feature Transformation of Datasets

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns

# import dataset
data= sns.load_dataset('titanic')
data.head(10) # show first 5 rows
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# ### **Random Sampling**

# %%
data.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 386         0       3    male   1.0      5      2  46.9000        S   Third
# 72          0       2    male  21.0      0      0  73.5000        S  Second
# 587         1       1    male  60.0      1      1  79.2000        C   First
# 702         0       3  female  18.0      0      1  14.4542        C   Third
# 548         0       3    male  33.0      1      1  20.5250        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 663         0       3    male  36.0      0      0   7.4958        S   Third
# 832         0       3    male   NaN      0      0   7.2292        C   Third
# 599         1       1    male  49.0      1      0  56.9292        C   First
# 570         1       2    male  62.0      0      0  10.5000        S  Second
# 56          1       2  female  21.0      0      0  10.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### **String Manipulation**

# %%
data_FRAME = pd.Series(['Life', 'Is  ', 'Sooo, BeautiFULL ' , 'and', ' Wonderful  ', np.nan , 'Enjoy, your, life'])
data_FRAME
# Out:
# 0                 Life
# 1                 Is
# 2    Sooo, BeautiFULL
# 3                  and
# 4          Wonderful
# 5                  NaN
# 6    Enjoy, your, life
# dtype: object

# %%
# lower or upper case changing of string
data_FRAME.str.lower() # lower case
data_FRAME.str.upper() # upper case
# Out:
# 0                 LIFE
# 1                 IS
# 2    SOOO, BEAUTIFULL
# 3                  AND
# 4          WONDERFUL
# 5                  NaN
# 6      ENJOY YOUR LIFE
# dtype: object

# %%
# stripping: removing extra spaces from the beginning and end of the string
data_FRAME.str.strip()
# Out:
# 0                 Life
# 1                   Is
# 2     Sooo, BeautiFULL
# 3                  and
# 4            Wonderful
# 5                  NaN
# 6    Enjoy, your, life
# dtype: object

# %%
# splitting string values based on comma
data_FRAME.str.split(',')
# Out:
# 0                   [Life]
# 1                   [Is  ]
# 2     [Sooo,  BeautiFULL ]
# 3                    [and]
# 4           [ Wonderful  ]
# 5                      NaN
# 6    [Enjoy,  your,  life]
# dtype: object

# %%
# concatenate string data 
data_FRAME.str.cat(sep='_')
# Out:
# 'Life_Is  _Sooo, BeautiFULL _and_ Wonderful  _Enjoy, your, life'

# %%
# find a string value in the dataset 
df.str.findall('S')
# Out:
# 0     []
# 1     []
# 2    [S]
# 3     []
# 4     []
# 5    NaN
# 6     []
# dtype: object
